# %% [markdown]
# <a href="https://colab.research.google.com/github/Hunter7210/Teste/blob/main/Heitor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando biblioteca panda
import pandas as pd # Biblioteca para dados bidimensionais
import numpy as np # Biblioteca de análise numérica
import matplotlib.pyplot as plt # Gráficos
import seaborn as sns # Este pacote serve para criar alguns gráficos mais bonitos.

# %%
df = pd.read_csv('bace.csv')

# %%
df.loc[0:203]
# Out:
#                                                    mol       CID  Class  \
# 0    O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...    BACE_1      1
# 1    Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...    BACE_2      1
# 2    S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...    BACE_3      1
# 3    S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...    BACE_4      1
# 4    S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...    BACE_5      1
# ..                                                 ...       ...    ...
# 199                            Clc1cc(ccc1)CCc1cccnc1N  BACE_201      0
# 200                                  n1ccc2c(cccc2)c1N  BACE_202      0
# 201                                  n1c2c(ccc1N)cccc2  BACE_203      0
# 202                  O1CC[NH+](CC1)CC(O)COc1cc(ccc1C)C  BACE_204      0
# 203                               O=C1NC(=NC(=C1)CCC)N  BACE_205      0
#
#      Model     pIC50         MW   AlogP  HBA  HBD  RB  ...  PEOE6 (PEOE6)  \
# ...

# %%
df.loc [0:203,'mol']
# Out:
# 0      O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...
# 1      Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...
# 2      S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...
# 3      S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...
# 4      S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...
#                              ...
# 199                              Clc1cc(ccc1)CCc1cccnc1N
# 200                                    n1ccc2c(cccc2)c1N
# 201                                    n1c2c(ccc1N)cccc2
# 202                    O1CC[NH+](CC1)CC(O)COc1cc(ccc1C)C
# 203                                 O=C1NC(=NC(=C1)CCC)N
# Name: mol, Length: 204, dtype: object

# %%
df.columns
# Out:
# Index(['mol', 'CID', 'Class', 'Model', 'pIC50', 'MW', 'AlogP', 'HBA', 'HBD',
#        'RB',
#        ...
#        'PEOE6 (PEOE6)', 'PEOE7 (PEOE7)', 'PEOE8 (PEOE8)', 'PEOE9 (PEOE9)',
#        'PEOE10 (PEOE10)', 'PEOE11 (PEOE11)', 'PEOE12 (PEOE12)',
#        'PEOE13 (PEOE13)', 'PEOE14 (PEOE14)', 'canvasUID'],
#       dtype='object', length=595)

# %%
df['Model'].unique()
# Out:
# array(['Train', 'Valid', 'Test'], dtype=object)

# %%
df.describe()
# Out:
#             Class       pIC50           MW       AlogP         HBA  \
# count  403.000000  403.000000   403.000000  403.000000  403.000000
# mean     0.744417    7.253140   512.830370    3.038959    4.009926
# std      0.436731    1.527962   155.245417    1.482498    1.791328
# min      0.000000    2.698970   138.187000   -4.361100    0.000000
# 25%      0.000000    6.688375   411.148100    2.283700    3.000000
# 50%      1.000000    7.958607   515.608700    3.004700    4.000000
# 75%      1.000000    8.244125   607.243745    3.843100    5.000000
# max      1.000000   10.522879  1350.473300    7.617400   12.000000
#
#               HBD          RB  HeavyAtomCount  ChiralCenterCount  \
# count  403.000000  403.000000      403.000000         403.000000
# mean     2.488834    9.317618       36.464020           1.223325
# std      1.748275    5.617436       10.877681           1.695693
# min      0.000000    0.000000       10.000000           0.000000
# ...

# %%
df.loc[0:203,['mol', 'Model']]
# Out:
#                                                    mol  Model
# 0    O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...  Train
# 1    Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...  Train
# 2    S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  Train
# 3    S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...  Train
# 4    S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  Train
# ..                                                 ...    ...
# 199                            Clc1cc(ccc1)CCc1cccnc1N  Train
# 200                                  n1ccc2c(cccc2)c1N  Train
# 201                                  n1c2c(ccc1N)cccc2  Train
# 202                  O1CC[NH+](CC1)CC(O)COc1cc(ccc1C)C  Train
# 203                               O=C1NC(=NC(=C1)CCC)N  Train
#
# [204 rows x 2 columns]

# %%
x =df.loc[0:203,['mol', 'Model']]

# %%
x.index
# Out:
# RangeIndex(start=0, stop=204, step=1)

# %%
x.mean()
# Out:
# <ipython-input-71-6f9184126d05>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x.mean()
# Series([], dtype: float64)

# %%
x[['mol', 'Model']]
# Out:
#                                                    mol  Model
# 0    O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...  Train
# 1    Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...  Train
# 2    S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  Train
# 3    S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...  Train
# 4    S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  Train
# ..                                                 ...    ...
# 199                            Clc1cc(ccc1)CCc1cccnc1N  Train
# 200                                  n1ccc2c(cccc2)c1N  Train
# 201                                  n1c2c(ccc1N)cccc2  Train
# 202                  O1CC[NH+](CC1)CC(O)COc1cc(ccc1C)C  Train
# 203                               O=C1NC(=NC(=C1)CCC)N  Train
#
# [204 rows x 2 columns]

# %%
x.max()
# Out:
# mol      s1ccnc1-c1cc(ccc1)C[C@H](NC(=O)[C@H](OC)C)[C@H...
# Model                                                Valid
# dtype: object

# %%
y =df1.describe()

# %%
x
# Out:
#                                                    mol  Model
# 0    O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...  Train
# 1    Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...  Train
# 2    S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  Train
# 3    S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...  Train
# 4    S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  Train
# ..                                                 ...    ...
# 199                            Clc1cc(ccc1)CCc1cccnc1N  Train
# 200                                  n1ccc2c(cccc2)c1N  Train
# 201                                  n1c2c(ccc1N)cccc2  Train
# 202                  O1CC[NH+](CC1)CC(O)COc1cc(ccc1C)C  Train
# 203                               O=C1NC(=NC(=C1)CCC)N  Train
#
# [204 rows x 2 columns]

# %%
y
# Out:
#                                                       mol  Model
# count                                                 204    204
# unique                                                204      2
# top     O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...  Train
# freq                                                    1    203
